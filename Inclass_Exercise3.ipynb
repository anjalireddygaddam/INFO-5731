# %% [markdown]
# <a href="https://colab.research.google.com/github/anjalireddygaddam/INFO-5731/blob/main/Inclass_Exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  My research question for this assignment is to find out which kind of crimes are most frequent in LA from 2010 to 2017.
Crime was very intriguing, because it is one of most life changing aspects people try to change,
alter and get punished for. In order to decrease the crime rate, the sheriff department try their 
best but sometimes fail due to many reasons. To help cops I created a scenario of analyzing 
crime scenes that took place from 2010 to 2017. by doing this we use a database to analyze future cases. 

The data needs be vast, for appropriate results. The data collected from kaggle is qualitative and quantitative and in
the form .csv

I haved used pandas and NLTK ( as i want to process text analytics) libraries and 
implemented tokenizations.
i wanted to display the top 10 crime types, hence i used FreqDist and displayed a graph plot.

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import nltk 
from nltk.tokenize import word_tokenize  
df = pd.read_csv("/content/drive/MyDrive/Crime_Data_2010_2017.csv")
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    DR Number Date Reported  ... Cross Street             Location
# 0    1208575     3/14/2013  ...          NaN  (33.9829, -118.3338)
# 1  102005556     1/25/2010  ...         15TH  (34.0454, -118.3157)
# 2        418     3/19/2013  ...          NaN   (33.942, -118.2717)
# 3  101822289    11/11/2010  ...         WALL  (33.9572, -118.2717)
# 4   42104479     1/11/2014  ...          NaN  (34.2009, -118.6369)
#
# [5 rows x 26 columns]

# %%
#Assign the Crime Code Description column as list 
word_tokens = list(df["Crime Code Description"])

#Use FreqDist function in NLTK library
freq = nltk.FreqDist(word_tokens)

#Convert the variable into dictionary
dict_freq = dict(freq)
print(dict_freq)

#Plot the top 10 Crime Codes description
freq.plot(10, cumulative=False)
# Out:
# {'INTIMATE PARTNER - SIMPLE ASSAULT': 55433, 'VEHICLE - STOLEN': 78461, 'VANDALISM - MISDEAMEANOR ($399 OR UNDER)': 50489, 'CRIMINAL HOMICIDE': 1467, 'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)': 3898, 'THEFT PLAIN - PETTY ($950 & UNDER)': 77866, 'STALKING': 1060, 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)': 20202, 'BATTERY - SIMPLE ASSAULT': 102912, 'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)': 295, 'DOCUMENT FORGERY / STOLEN FELONY': 12843, 'BIKE - STOLEN': 3780, 'ROBBERY': 42489, 'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02': 623, 'ATTEMPTED ROBBERY': 6128, 'RESISTING ARREST': 1788, 'TRESPASSING': 8232, 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036': 40360, 'COUNTERFEIT': 525, 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT': 42239, 'THROWING OBJECT AT MOVING VEHICLE': 714, 'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER': 1150, 'CRIMINAL THREATS - NO WEAPON DISPLAYED': 32059, 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114': 49333, 'BURGLARY FROM VEHICLE': 81408, 'BATTERY WITH SEXUAL CONTACT': 5410, 'OTHER MISCELLANEOUS CRIME': 12243, 'BURGLARY': 78378, 'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)': 1346, 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT': 4709, 'INDECENT EXPOSURE': 1663, 'CHILD NEGLECT (SEE 300 W.I.C.)': 3714, 'OTHER ASSAULT': 706, 'THEFT, PERSON': 6641, 'BOMB SCARE': 577, 'EXTORTION': 775, 'RAPE, FORCIBLE': 4602, 'THEFT PLAIN - ATTEMPT': 917, 'THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)': 13972, 'INTIMATE PARTNER - AGGRAVATED ASSAULT': 2782, 'DISTURBING THE PEACE': 1817, 'CHILD ANNOYING (17YRS & UNDER)': 3143, 'SHOTS FIRED AT INHABITED DWELLING': 1355, 'BATTERY POLICE (SIMPLE)': 2282, 'BRANDISH WEAPON': 4123, 'CRUELTY TO ANIMALS': 895, 'SEXUAL PENTRATION WITH A FOREIGN OBJECT': 784, 'THEFT OF IDENTITY': 68422, 'ARSON': 1678, 'BURGLARY, ATTEMPTED': 6692, 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)': 38517, 'VIOLATION OF COURT ORDER': 11900, 'LETTERS, LEWD': 12112, 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)0060': 5043, 'BURGLARY FROM VEHICLE, ATTEMPTED': 1614, 'FALSE IMPRISONMENT': 495, 'BUNCO, GRAND THEFT': 2363, 'PURSE SNATCHING': 656, 'VIOLATION OF RESTRAINING ORDER': 8520, 'RAPE, ATTEMPTED': 589, 'BUNCO, PETTY THEFT': 1472, 'KIDNAPPING': 1179, 'LEWD CONDUCT': 634, 'PROWLER': 523, 'VEHICLE - ATTEMPT STOLEN': 1644, 'PIMPING': 280, 'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM0065': 15, 'PEEPING TOM': 577, 'SEX, UNLAWFUL': 2537, 'BIKE - ATTEMPTED STOLEN': 6, 'THEFT FROM PERSON - ATTEMPT': 151, 'PICKPOCKET': 228, 'RECKLESS DRIVING': 93, 'ORAL COPULATION': 739, 'THREATENING PHONE CALLS/LETTERS': 1816, 'DISHONEST EMPLOYEE - PETTY THEFT': 51, 'UNAUTHORIZED COMPUTER ACCESS': 528, 'DISCHARGE FIREARMS/SHOTS FIRED': 1863, 'CHILD STEALING': 651, 'CREDIT CARDS, FRAUD USE ($950.01 & OVER)': 415, 'DRIVING WITHOUT OWNER CONSENT (DWOC)': 202, 'BUNCO, ATTEMPT': 172, 'BRIBERY': 24, 'CREDIT CARDS, FRAUD USE ($950 & UNDER': 74, 'WEAPONS POSSESSION/BOMBING': 100, 'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT': 991, 'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER': 831, 'SHOPLIFTING - ATTEMPT': 72, 'ILLEGAL DUMPING': 252, 'KIDNAPPING - GRAND ATTEMPT': 428, 'PICKPOCKET, ATTEMPT': 5, 'PURSE SNATCHING - ATTEMPT': 25, 'THEFT FROM MOTOR VEHICLE - ATTEMPT': 514, 'BATTERY ON A FIREFIGHTER': 121, 'DOCUMENT WORTHLESS ($200.01 & OVER)': 127, 'FAILURE TO YIELD': 67, 'VIOLATION OF TEMPORARY RESTRAINING ORDER': 442, 'FALSE POLICE REPORT': 216, 'DISHONEST EMPLOYEE - GRAND THEFT': 47, 'ABORTION/ILLEGAL': 3, 'CONTRIBUTING': 112, 'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $400': 105, 'DRUNK ROLL': 11, 'THEFT, COIN MACHINE - PETTY ($950 & UNDER)': 76, 'BOAT - STOLEN': 170, 'DISRUPT SCHOOL': 25, 'INCITING A RIOT': 6, 'FAILURE TO DISPERSE': 18, 'PANDERING': 126, 'TILL TAP - PETTY ($950 & UNDER)': 32, 'LYNCHING - ATTEMPTED': 11, 'CONSPIRACY': 25, 'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)0132': 3, 'CHILD ABANDONMENT': 48, 'TELEPHONE PROPERTY - DAMAGE': 2 ...
